# %% [markdown]
# # Pandas Practical Test (30 Marks)
#
# Dataset: NetFlix.csv
#
# Time: 1 Hour
#
# Maximum Marks: 30

# %% [markdown]
# Name:
#
# College-Id:

# %% [markdown]
# Q1. Load the dataset and display the first 10 records.

# %%
import pandas as pd
df = pd.read_csv("Netflix.csv")
df.head(10)
# Out:
#   show_id     type                                      title  \
# 0      s1  TV Show                                         3%
# 1     s10    Movie                                       1920
# 2    s100    Movie                                 3 Heroines
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4   s1001  TV Show                             Blue Planet II
# 5   s1002    Movie                                  Blue Ruin
# 6   s1003    Movie                                Blue Streak
# 7   s1004    Movie                             Blue Valentine
# 8   s1005    Movie                               BluffMaster!
# 9   s1006    Movie        Blurred Lines: Inside the Art World
#
#            director                                               cast  \
# 0               NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1      Vikram Bhatt  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# ...

# %% [markdown]
# Q2. Find:
#
# a) Number of rows and columns
#
# b) Data types of all columns

# %%
df.shape

# df.dtypes
# Out:
# (7787, 12)

# %% [markdown]
# Q3. Display the names of all columns in the dataset.

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description'],
#       dtype='object')

# %% [markdown]
# Q4. Find the number of missing values present in each column.

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %% [markdown]
# Q5. How many Movies and TV Shows are available in the dataset?

# %%
(df["type"] == 'Movie').count()

(df["type"] == 'TV Show').count()
# Out:
# np.int64(7787)

# %% [markdown]
# Q6. Display all titles released after 2020.

# %%
titles_after_2020 = df[df['release_year'] > 2020]['title']
print(titles_after_2020)
# Out:
# 250                                       Carmen Sandiego
# 319                                              Charming
# 397     Chris Rock Total Blackout: The Tamborine Exten...
# 492                                             Cobra Kai
# 574               Crack: Cocaine, Corruption & Conspiracy
# 589                           Creating The Queen's Gambit
# 869                                        Disenchantment
# 962                                   Dream Home Makeover
# 1477                                    Gabby's Dollhouse
# 1860                        Headspace Guide to Meditation
# 1937                                                Hilda
# 1950                               History of Swear Words
# 2245                  Inside the World’s Toughest Prisons
# 3138                                                Lupin
# 3431                   Mighty Little Bheem: Kite Festival
# 3528                                              Monarca
# ...

# %% [markdown]
# Q7. Find the 10 oldest titles in the dataset based on release_year.

# %%
df.sort_values("release_year").head(10)
# Out:
#      show_id     type                                             title  \
# 4298   s4868  TV Show                 Pioneers: First Women Filmmakers*
# 4402   s4961    Movie                                    Prelude to War
# 5688   s6118    Movie                              The Battle of Midway
# 7423   s7680    Movie                   WWII: Report from the Aleutians
# 7353   s7617    Movie                Why We Fight: The Battle of Russia
# 7049   s7343    Movie     Undercover: How to Operate Behind Enemy Lines
# 6335   s6700    Movie                                 The Negro Soldier
# 6287   s6658    Movie  The Memphis Belle: A Story of a\nFlying Fortress
# 6966   s7269    Movie                                  Tunisian Victory
# 3820   s4437    Movie                          Nazi Concentration Camps
#
#                                                director  \
# 4298                                                NaN
# 4402                                        Frank Capra
# ...

# %% [markdown]
# Q8. Find all content having rating "PG-13" and display their titles.

# %%
df[df['rating'] == "PG-13"]['title']
# Out:
# 6                           Blue Streak
# 13                             3 Idiots
# 85                        Brain on Fire
# 121     Bring It On: Worldwide Showdown
# 155                               Bully
#                      ...
# 7752                          Blackfish
# 7754                     3 Days to Kill
# 7755                           Blackway
# 7776                      3 Generations
# 7785                       Blue Jasmine
# Name: title, Length: 386, dtype: object

# %% [markdown]
# Q9. Count the number of titles available in each rating category.

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: count, dtype: int64

# %% [markdown]
# Q10. Find the average duration of all Movies and TV Shows separately.

# %%
movie_avg = df[df['type'] == 'Movie']['duration'].mean()
print(movie_avg)

TV_avg = df[df['type'] == 'TV Show']['duration'].mean()
print(TV_avg)
# Out:
# 99.30797842663195
# 1.7759336099585061

# %% [markdown]
# Q11. Find the director who has directed the maximum number of titles.

# %%
df["director"].value_counts().head(1)
# Out:
# director
# Raúl Campos, Jan Suter    18
# Name: count, dtype: int64

# %% [markdown]
# Q12. Find the release year that contains the maximum number of titles.

# %% [markdown]
# Q13. Display all titles whose genre contains the word "Drama".

# %% [markdown]
# Q14. Find the top 5 most common genres.

# %%
df["genres"].value_counts().head(5)
# Out:
# genres
# Documentaries                                       334
# Stand-Up Comedy                                     321
# Dramas, International Movies                        320
# Comedies, Dramas, International Movies              243
# Dramas, Independent Movies, International Movies    215
# Name: count, dtype: int64

# %% [markdown]
# Q15. Export all Movies released after 2018 to a new CSV file named recent_movies.csv.
