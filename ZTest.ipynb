# %%
import scipy.stats as st
import numpy as np
st.norm.ppf(0.95)
# Out:
# np.float64(1.6448536269514722)

# %%
s_x = 90
p_u = 82
p_std = 20
n = 81
ap = 0.05
# z_cal = (s_x-p_u)/(p_std/np.sqrt(n))
# z_cal
# Out:
# np.float64(3.5999999999999996)

# %%
z_table = st.norm.ppf(1-ap)

# %%
# if z_table < z_cal:
#     print("ha is right")
# else :
#     print("ho is right")
# Out:
# ha is right

# %%
old_design_data = np.array([45.2, 42.8, 38.9, 43.5, 41.0, 44.6, 40.5, 42.7, 39.8, 41.4, 44.3, 39.6, 44.0, 43.1, 38.7, 43.9, 42.0, 41.9, 42.8, 43.7, 41.3, 40.9, 42.5, 41.6])
new_design_data = np.array([48.5, 46.0, 50.2, 47.8, 48.7, 49.8, 48.0, 50.5, 49.8, 49.6, 48.2, 48.6, 49.3, 49.0, 50.0, 48.4, 49.3, 49.6, 49.8, 50.0, 50.4, 48.1, 49.2, 50.7])

# %%
pop_std = 2.5
n_sp = len(new_design_data)
alpha = 0.05

# %%
mean_new = np.mean(new_design_data)
mean_old = np.mean(old_design_data)

# %%
z_cal = (mean_new-mean_old)/(pop_std/np.sqrt(n_sp))
z_cal
# Out:
# np.float64(13.782462286060024)

# %%
z_table = st.norm.ppf(1-alpha)
z_table
# Out:
# np.float64(1.6448536269514722)

# %%
if z_cal>z_table:
    print("Ha is right")
else :
    print("Ho is right")
# Out:
# Ha is right
