# %%
 # Array - Homogenous array of fixed size
import numpy as np

# %%
l1 = [20, 30, 40]
l2 = [60,70,80]
print(l1 + l2)
# Out:
# [20, 30, 40, 60, 70, 80]

# %%
a = np.array(l1)
b = np.array(l2)
print(l1)
print(l2)
# Out:
# [20, 30, 40]
# [60, 70, 80]

# %%
print("Harnoor Kaur")
# Out:
# Harnoor Kaur

# %%
arr = np.array([10, 20, 30, 40, 50])
print(arr)
print(type(arr))
# Out:
# [10 20 30 40 50]
# <class 'numpy.ndarray'>

# %%
print(arr[0 : 3])
print(arr[1 : 4])
print(arr[:3])
# Out:
# [10 20 30]
# [20 30 40]
# [10 20 30]

# %%
print(np.shape(arr))
print(np.size(arr))
print(np.ndim(arr))
print(arr.dtype)
# Out:
# (5,)
# 5
# 1
# int64
