# %%
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
dataset = pd.read_csv("diabetes.csv")
dataset.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
x = dataset.iloc[:,:-1]
y = dataset["Outcome"]

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
fs = SequentialFeatureSelector(
    lr,
    n_features_to_select=8,
    direction='forward'
)

fs.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 7
#       1 fs = SequentialFeatureSelector(
#       2     lr,
#       3     n_features_to_select=8,
#       4     direction='forward'
#       5 )
# ----> 7 fs.fit(x, y)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\feature_selection\_sequential.py:256, in SequentialFeatureSelector.fit(self, X, y, **params)
#     254 elif isinstance(self.n_features_to_select, Integral):
#     255     if self.n_features_to_select >= n_features:
# --> 256         raise ValueError("n_features_to_select must be < n_features.")
#     257     self.n_features_to_select_ = self.n_features_to_select
#     258 elif isinstance(self.n_features_to_select, Real):
#
# ValueError: n_features_to_select must be < n_features.

# %%
fs.feature_names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 fs.feature_names
#
# AttributeError: 'SequentialFeatureSelector' object has no attribute 'feature_names'
